# %%
# This will import all the widgets
# and modules which are available in
# tkinter and ttk module
from tkinter import * 
from tkinter.ttk import *

#--------------------------------------------------------------------------------------------------------------------------------------------
# This function runs the scanner
def info():
    a = %run BookFinder2.ipynb
    return a

def read():
    with open('results.txt') as f:
        lines = f.readlines()
    return lines

def new_book(title, author, ISBN, year, owner):
    sql = '''INSERT OR IGNORE INTO library (title, author, ISBN, year, owner, holder) 
                   VALUES (?, ?, ?, ?, ?, ?) '''
    row = (title, author, ISBN, year, owner, owner)
    cursor.execute(sql, row)
    conn.commit()

def correct_book():
    text_file = open("results.txt", "r")

    # Splits the element by "\n"
    lines = text_file.readlines()
    text_file.close()
    new_book(lines[1],lines[2],lines[0],lines[3],lines[2])


def runBar():
    open("results.txt",'w')
    #%run Barcode_Reader_Final_Version.ipynb                                       don't forget to uncomment this
    newWindow = Toplevel(master)
    newWindow.title("Result")
    newWindow.geometry("600x300")
    info()
    Label(newWindow, text = read()).pack()
   

    btn = Button(newWindow, 
             text ="Correct Book", command = correct_book) #now add to database
    btn.pack(pady = 10)

    btn2 = Button(newWindow, 
             text ="Incorrect Book", command = newWindow.destroy) #colapse all
    btn2.pack(pady = 10)
    #open("results.txt", "w").close()



    #Run bookfinder and then open window with summary
#--------------------------------------------------------------------------------------------------------------------------------------------
'''MAIN WINDOW'''

# creates a Tk() object
master = Tk()

master.title("MSP Database")

# sets the geometry of main 
# root window
master.geometry("600x300")
#--------------------------------------------------------------------------------------------------------------------------------------------
'''ADD WINDOW'''

# function to open a new window 
# on a button click
def openAddBook():
      
    # Toplevel object which will 
    # be treated as a new window
    newWindow = Toplevel(master)
  
    # sets the title of the
    # Toplevel widget
    newWindow.title("Add a book to the MSP database")
  
    # sets the geometry of toplevel
    newWindow.geometry("600x300")
  
    # A Label widget to show in toplevel
    Label(newWindow, 
          text ="Insert Name then Scan Book").grid(row=1,column=0)
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
    name_var=StringVar()

    def submit():

        name = name_var.get()
        file = open ("name.txt",'a') # open text document
        data = file.write(name) # write the name
        file.close() # close the text document
        name_var.set("")
     

    # creating a label for
    # name using widget Label
    name_label = Label(newWindow, text = 'Name')
  
    # creating a entry for input
    # name using widget Entry
    name_entry = Entry(newWindow, textvariable= name_var, width=20)

    # name = Entry(newWindow,width=20) # to get this use name.get()
    # name.pack(pady=10)

    

    name_label.grid(row=0,column=0)
    name_entry.grid(row=0,column=1)


#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

    def all():
        runBar()
        submit()

    btn = Button(newWindow, 
             text ="Scan Book", command = all)
    btn.grid(row=2,column=1)   
    
#--------------------------------------------------------------------------------------------------------------------------------------------
# '''SEARCH WINDOW'''

# def openSearchBook():
      
#     # Toplevel object which will 
#     # be treated as a new window
#     newWindow = Toplevel(master)
  
#     # sets the title of the
#     # Toplevel widget
#     newWindow.title("Search Book")
  
#     # sets the geometry of toplevel
#     newWindow.geometry("600x300")
  

#     # A Label widget to show in toplevel
#     Label(newWindow, 
#           text ="This is a new window").pack()
def search_bar():
    # %run Search_bar.ipynb

#--------------------------------------------------------------------------------------------------------------------------------------------
'''MAIN WINDOW'''

label = Label(master, 
              text ="Welcome to the MSP Database")
  
label.pack(pady = 10)
  
# a button widget which will open a 
# new window on button click
btn = Button(master, 
             text ="Add Book", 
             command = openAddBook)
btn.pack(pady = 10)

btn2 = Button(master, 
             text ="Search Book", command = search_bar)
btn2.pack(pady = 10)
  
# mainloop, runs infinitely
mainloop()
